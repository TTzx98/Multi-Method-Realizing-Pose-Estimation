# %%
import torch
import numpy as np
import os
import scipy.io
from PIL import Image
from torchvision.transforms import *
from torch.utils.data import DataLoader

def standardize_label(label, orim):  #保证了原图像的坐标的准确
    label_std = []
    for idx, _ in enumerate(label):
        labelX = label[idx][0] / orim.size[0]  #x的值除于原始图像的宽
        labelY = label[idx][1] / orim.size[1]  #y的值除于原始图像的高
        label_std.append([labelX, labelY])
    label_std = np.array(label_std)
    # print(label_std)
    return label_std

class PoseImageDataset(torch.utils.data.Dataset):
    def __init__(self, transforms, imagespath='', labelsfilepath=''):

        imgs_list = sorted(os.listdir(os.path.join(imagespath)))  # 获得文件夹内的图片的名称列表
        self.filenames = imgs_list
        self.annotationmat = scipy.io.loadmat(labelsfilepath)
        # print(self.annotationmat) #加载.mat文件的数据
        joints = self.annotationmat['joints']
        # print(joints) # 只加载'joints'键的数据
        print(joints.shape) # (3, 14, 2000)
        joints = np.swapaxes(joints, 2, 0)
#         joints = np.swapaxes(joints, 2, 1) # used in lspet
        print(joints.shape)

        labels = []
        images = []
        origin_image_size = []

        for file_idx, file_name in enumerate(imgs_list):
            fn = imgs_list[file_idx]
            orim = Image.open(os.path.join(imagespath,fn))
            origin_image_size.append(orim.size)
            # print(orim)   # Image.open根据拼接的路径获取图像信息
            # print(self.transforms)
            image1 = transforms(orim)  #将图像信息归一化
            # print(image1.shape)
            label = joints[file_idx]
            # print(label)
            #standardizing标准化
            label = standardize_label(label, orim)
            # print(label)
            label = torch.from_numpy(label)  # torch.from_numpy()方法把数组转换成张量，且二者共享内存，对张量进行修改比如重新赋值，那么原始数组也会相应发生改变。
            label1 = label.type(torch.FloatTensor)
            images.append(image1)
            labels.append(label1)
#             print(label1)
#             break
            
        self.images = images
        self.labels = labels
        self.orim_size = origin_image_size
        

    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx], self.orim_size[idx]

    def __len__(self):
        return len(self.filenames)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # 优先使用显卡
print(f"using {device}")

image_path = './dataset/lsp/images'
labels_file_path = './dataset/lsp/joints.mat'
# image_path = './dataset/lspet/images'
# labels_file_path = './dataset/lspet/joints.mat'
# image_size = 128
# image_size = 256 # blazepose
image_size = 196 # deeppose
batch_size = 32
transforms = Compose([
    Resize((image_size,image_size)),
    ToTensor(),  #张量化
    #ToTensor()能够把灰度范围从0-255变换到0-1之间，
    # 而transform.Normalize()则把0-1变换到(-1,1).具体地说，对每个通道而言
    Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])

#加载自己的数据集
dataset = PoseImageDataset(transforms, image_path, labels_file_path)
# print(dataset.images.shape)  #(2000, 14, 3)

#数据集划分
total = len(dataset)
print(total)
train_size = int(total * 0.5)
test_size = total - train_size
lengths = [train_size, test_size]
train_dataset, test_dataset = torch.utils.data.dataset.random_split(dataset, lengths)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# using cuda
# (3, 14, 2000)
# (2000, 14, 3)
# 2000

# %%
import matplotlib.pyplot as plt

dataiter = iter(train_dataloader)
print(len(dataiter.next()))
images, labels, int_labels= dataiter.next()
img = images[0]
img = img.numpy()
img = np.transpose(img, (1, 2, 0))
img = img[:,:,-1::]
# plt.imshow(img)
plt.figure()
print(labels[0])
print(labels[0].shape)
print(labels[0][0])
x = [labels[0][i][0] * image_size for i in range(14)]
y = [labels[0][i][1] * image_size for i in range(14)]
print(np.array(x))
print(np.array(y))
plt.scatter(np.array(x), np.array(y), color = 'red', s = 4)
# print(len(int_labels[0]))
plt.imshow(img)
# Out:
# 3
# tensor([[0.6457, 0.5403],
#         [0.6196, 0.5931],
#         [0.5813, 0.5244],
#         [0.5506, 0.5105],
#         [0.5414, 0.5519],
#         [0.4800, 0.5838],
#         [0.5352, 0.6274],
#         [0.4479, 0.6045],
#         [0.4555, 0.5426],
#         [0.5107, 0.4555],
#         [0.4479, 0.3959],
#         [0.4111, 0.3684],
#         [0.3144, 0.2927],
#         [0.4831, 0.3569]])
# torch.Size([14, 2])
# tensor([0.6457, 0.5403])
# [126.564926 121.43681  113.929886 107.92434  106.11097   94.08038
#  104.90206   87.78236   89.283745 100.10542   87.78236   80.56791
#   61.61534   94.68484 ]
# [105.89206  116.23936  102.77331  100.06261  108.16555  114.43222
#  122.972374 118.483696 106.35843   89.27812   77.59006   72.19781
#   57.361843  69.95347 ]

# %%
import torch
import torch.nn as nn

class DeepPose(nn.Module):
    def __init__(self):
        super(DeepPose, self).__init__()

        self.model = torch.nn.Sequential(

        nn.Conv2d(in_channels=3, out_channels=96, kernel_size=11, stride=4, padding=0),
        nn.ReLU(inplace=True),
        nn.LocalResponseNorm(size=2, alpha=2e-05, beta=0.75, k=1),  #局部响应归一化层
        nn.MaxPool2d(kernel_size=3, stride=2, padding=0),

        nn.Conv2d(in_channels=96, out_channels=256, kernel_size=5, stride=1, padding=0),
        nn.ReLU(inplace=True),
        nn.LocalResponseNorm(size=2, alpha=2e-05, beta=0.75, k=1),
        nn.MaxPool2d(kernel_size=3, stride=2, padding=0),

        nn.Conv2d(in_channels=256, out_channels=384, kernel_size=3, stride=1, padding=0),

        nn.ReLU(inplace=True),

        nn.Conv2d(in_channels=384, out_channels=384, kernel_size=3, stride=1, padding=0),
        nn.ReLU(inplace=True),

        nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, stride=1, padding=0),
        nn.ReLU(inplace=True),
        nn.MaxPool2d(kernel_size=3, stride=2, padding=0),

        nn.Flatten(),
        nn.Linear(in_features=256, out_features=4096),
        nn.ReLU(inplace=True),
        nn.Dropout(p=0.6),

        nn.Linear(in_features=4096, out_features=4096),
        nn.ReLU(inplace=True),
        nn.Dropout(p=0.6),
        nn.Linear(in_features=4096, out_features=28)
        )


    def forward(self, input):
        endOut = self.model(input)
        return endOut

# model = DeepPose().to(device)
model = torch.load("DeepPose.model").to(device)
print(model)
# Out:
# DeepPose(
#   (model): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4))
#     (1): ReLU(inplace=True)
#     (2): LocalResponseNorm(2, alpha=2e-05, beta=0.75, k=1)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1))
#     (5): ReLU(inplace=True)
#     (6): LocalResponseNorm(2, alpha=2e-05, beta=0.75, k=1)
#     (7): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Flatten(start_dim=1, end_dim=-1)
#     (16): Linear(in_features=256, out_features=4096, bias=True)
#     (17): ReLU(inplace=True)
#     (18): Dropout(p=0.6, inplace=False)
#     (19): Linear(in_features=4096, out_features=4096, bias=True)
#     (20): ReLU(inplace=True)
#     (21): Dropout(p=0.6, inplace=False)
#     (22): Linear(in_features=4096, out_features=28, bias=True)
#   )
# )

# %%
import torch
import torch.nn as nn
import torchvision
# 'resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152'
resnet = torchvision.models.resnet34(pretrained=True)
in_features = resnet.fc.in_features
resnet.fc = nn.Sequential(nn.Linear(in_features, 28))
model = resnet.to(device)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=28, bias=True)
#   )
# )

# %%
import torch
import torch.nn as nn
import torchvision

model = torch.load("ResNet34.model").to(device)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=28, bias=True)
#   )
# )

# %%
def train():
#     model.train()
    loss_value = 0
    for tmp, (images, labels, _) in enumerate(train_dataloader):
        images, labels = images.to(device), labels.to(device)  #方便用于gpu
        
        predict = model(images)  # 把图像数据放进model里
        
        predict = predict.view(labels.shape)

        loss_value = lossFunction(predict, labels)  # 将标签和图像数据同时放入

        # 反向传播
        optimizer.zero_grad()  # 梯度置零，也就是把loss关于weight的导数变成0.
        loss_value.backward()
        optimizer.step()

        if tmp > 0:
            if (tmp % 10) == 0:
#                 print('checkpoint guardado' + str(tmp))
                torch.save(model.state_dict(), './model_checkpoint.chp')

    return loss_value.item()

def test():
#     model.eval()
    test_loss_total = 0

    images_accuracy = []
    
    with torch.no_grad():
        for images, labels, orim_size in test_dataloader:
            images, labels = images.to(device), labels.to(device)
            predict = model(images)  # 把图像数据放进model里

            predict = predict.view(labels.shape)  #将预测的关节点坐标整理成原始坐标的形状

            for idx, _ in enumerate(labels):
                image_accuracy = accuracy_compute(predict[idx], labels[idx], image_size)
                images_accuracy.append(image_accuracy)

            loss_value = lossFunction(predict, labels)  # 将标签和图像数据同时放入

            test_loss_total += loss_value


        accuracy = sum(images_accuracy) / len(images_accuracy)  #batch的准确率
        test_loss_total /= len(test_dataset)

#         print("准确率：", accuracy)
        return test_loss_total, accuracy


def accuracy_compute(predict, labels, img_size, deviation_distance = 5):
    #处理一个图片的准确率
    joints = 14
    correct = 0  #正确的个数

    for idx, _ in enumerate(labels):
        # print(predict[idx] * img_size, labels[idx] * img_size)
        deviation = ((predict[idx] - labels[idx]) * img_size) ** 2  #使用距离公式
        deviation = sum(deviation)
        # print(deviation)
        # print(deviation_distance ** 2)

        if deviation <= deviation_distance ** 2:
            correct += 1

    accuary = correct / joints

    return accuary

# %%
test_loss, accuracy = [], []

lossFunction = torch.nn.MSELoss(reduction='sum')  #均方差损失函数
optimizer = torch.optim.Adam(model.parameters(), lr=0.00002)  # 优化器 0.00001

EPOCHS = 800
# 批训练EPOCHS
for epoch in range(1, EPOCHS+1):

    train_loss = train()  #训练

    test_loss_, accuracy_ = test()   #测试
    print(f"第{epoch}/{EPOCHS}次训练，训练损失值为{train_loss}, 测试损失值为{test_loss_},测试准确率为{accuracy_}")

    test_loss1 = test_loss_.detach().cpu().numpy()
    test_loss.append(test_loss1)
    accuracy.append(accuracy_)

model_name = "ResNet34"
torch.save(model, model_name + ".model")
# Out:
# 第1/800次训练，训练损失值为33.982357025146484, 测试损失值为3.6957244873046875,测试准确率为0.0033571428571428598
# 第2/800次训练，训练损失值为12.424959182739258, 测试损失值为1.7431904077529907,测试准确率为0.00621428571428571
# 第3/800次训练，训练损失值为6.516226768493652, 测试损失值为1.3652544021606445,测试准确率为0.006642857142857138
# 第4/800次训练，训练损失值为4.160938262939453, 测试损失值为1.2776458263397217,测试准确率为0.006928571428571423
# 第5/800次训练，训练损失值为2.939997434616089, 测试损失值为1.24452543258667,测试准确率为0.006999999999999994
# 第6/800次训练，训练损失值为2.1626486778259277, 测试损失值为1.2307747602462769,测试准确率为0.00792857142857142
# 第7/800次训练，训练损失值为1.6108627319335938, 测试损失值为1.2265435457229614,测试准确率为0.008285714285714278
# 第8/800次训练，训练损失值为1.2165062427520752, 测试损失值为1.226534128189087,测试准确率为0.008142857142857134
# 第9/800次训练，训练损失值为0.9366236329078674, 测试损失值为1.2275844812393188,测试准确率为0.008785714285714273
# 第10/800次训练，训练损失值为0.741763710975647, 测试损失值为1.237512469291687,测试准确率为0.008142857142857134
# 第11/800次训练，训练损失值为0.6076897978782654, 测试损失值为1.2394753694534302,测试准确率为0.007999999999999993
# 第12/800次训练，训练损失值为0.6164391040802002, 测试损失值为1.2636356353759766,测试准确率为0.007642857142857136
# 第13/800次训练，训练损失值为0.4303510785102844, 测试损失值为1.2509430646896362,测试准确率为0.008428571428571419
# 第14/800次训练，训练损失值为0.3956840932369232, 测试损失值为1.2507948875427246,测试准确率为0.008071428571428563
# 第15/800次训练，训练损失值为0.37372884154319763, 测试损失值为1.2596756219863892,测试准确率为0.00792857142857142
# 第16/800次训练，训练损失值为0.3793545067310333, 测试损失值为1.2665950059890747,测试准确率为0.007785714285714278
# 第17/800次训练，训练损失值为0.35309451818466187, 测试损失值为1.2623130083084106,测试准确率为0.008142857142857132
# 第18/800次训练，训练损失值为0.3817528486251831, 测试损失值为1.2547645568847656,测试准确率为0.008142857142857136
# 第19/800次训练，训练损失值为0.3769337236881256, 测试损失值为1.2435798645019531,测试准确率为0.008642857142857134
# 第20/800次训练，训练损失值为0.3572050929069519, 测试损失值为1.2380608320236206,测试准确率为0.007571428571428564
# 第21/800次训练，训练损失值为0.4233672618865967, 测试损失值为1.248555064201355,测试准确率为0.008071428571428563
# 第22/800次训练，训练损失值为0.3649437427520752, 测试损失值为1.2613043785095215,测试准确率为0.007642857142857134
# 第23/800次训练，训练损失值为0.3382112383842468, 测试损失值为1.231053352355957,测试准确率为0.010142857142857127
# 第24/800次训练，训练损失值为0.48098355531692505, 测试损失值为1.2247473001480103,测试准确率为0.007714285714285704
# 第25/800次训练，训练损失值为0.4314853549003601, 测试损失值为1.2253159284591675,测试准确率为0.009214285714285703
# 第26/800次训练，训练损失值为0.4980998635292053, 测试损失值为1.201358675956726,测试准确率为0.009214285714285703
# 第27/800次训练，训练损失值为0.6049336194992065, 测试损失值为1.1682415008544922,测试准确率为0.009071428571428558
# 第28/800次训练，训练损失值为0.4292096495628357, 测试损失值为1.1457756757736206,测试准确率为0.009714285714285701
# 第29/800次训练，训练损失值为0.54029381275177, 测试损失值为1.12083101272583,测试准确率为0.009499999999999986
# 第30/800次训练，训练损失值为0.5314056277275085, 测试损失值为1.130336880683899,测试准确率为0.009214285714285703
# 第31/800次训练，训练损失值为0.2810545563697815, 测试损失值为1.105709433555603,测试准确率为0.009214285714285704
# 第32/800次训练，训练损失值为0.309447705745697, 测试损失值为1.0919694900512695,测试准确率为0.009999999999999985
# 第33/800次训练，训练损失值为0.2516964077949524, 测试损失值为1.0972926616668701,测试准确率为0.009428571428571416
# 第34/800次训练，训练损失值为0.22380906343460083, 测试损失值为1.0863473415374756,测试准确率为0.009714285714285705
# 第35/800次训练，训练损失值为0.23272758722305298, 测试损失值为1.0652925968170166,测试准确率为0.008999999999999992
# 第36/800次训练，训练损失值为0.18851667642593384, 测试损失值为1.0675381422042847,测试准确率为0.009357142857142845
# 第37/800次训练，训练损失值为0.2367205023765564, 测试损失值为1.0779271125793457,测试准确率为0.010714285714285695
# 第38/800次训练，训练损失值为0.1704714000225067, 测试损失值为1.0810799598693848,测试准确率为0.009499999999999988
# 第39/800次训练，训练损失值为0.21228745579719543, 测试损失值为1.067933201789856,测试准确率为0.00964285714285713
# 第40/800次训练，训练损失值为0.1946200579404831, 测试损失值为1.0724626779556274,测试准确率为0.009285714285714272
# 第41/800次训练，训练损失值为0.23209328949451447, 测试损失值为1.0691132545471191,测试准确率为0.009642857142857134
# 第42/800次训练，训练损失值为0.21026118099689484, 测试损失值为1.0519648790359497,测试准确率为0.009642857142857127
# 第43/800次训练，训练损失值为0.32465216517448425, 测试损失值为1.0621453523635864,测试准确率为0.009214285714285701
# 第44/800次训练，训练损失值为0.2784331738948822, 测试损失值为1.0721060037612915,测试准确率为0.009428571428571415
# 第45/800次训练，训练损失值为0.26853805780410767, 测试损失值为1.0699260234832764,测试准确率为0.011071428571428552
# 第46/800次训练，训练损失值为0.26066190004348755, 测试损失值为1.0619920492172241,测试准确率为0.009571428571428559
# 第47/800次训练，训练损失值为0.2577939033508301, 测试损失值为1.0451894998550415,测试准确率为0.011071428571428553
# 第48/800次训练，训练损失值为0.3361019492149353, 测试损失值为1.0037535429000854,测试准确率为0.009714285714285701
# 第49/800次训练，训练损失值为0.31107646226882935, 测试损失值为0.9601122736930847,测试准确率为0.010428571428571412
# 第50/800次训练，训练损失值为0.2258530557155609, 测试损失值为0.9573497176170349,测试准确率为0.01207142857142855
# 第51/800次训练，训练损失值为0.25468379259109497, 测试损失值为0.9968910813331604,测试准确率为0.011214285714285694
# 第52/800次训练，训练损失值为0.2793698012828827, 测试损失值为1.028522253036499,测试准确率为0.009928571428571415
# 第53/800次训练，训练损失值为0.24793998897075653, 测试损失值为0.9874452352523804,测试准确率为0.011285714285714267
# 第54/800次训练，训练损失值为0.2961004376411438, 测试损失值为0.951327383518219,测试准确率为0.012714285714285692
# 第55/800次训练，训练损失值为0.23751817643642426, 测试损失值为0.9395996332168579,测试准确率为0.01371428571428569
# 第56/800次训练，训练损失值为0.30422523617744446, 测试损失值为0.9474833607673645,测试准确率为0.011142857142857125
# 第57/800次训练，训练损失值为0.20447790622711182, 测试损失值为0.934679388999939,测试准确率为0.012428571428571405
# 第58/800次训练，训练损失值为0.21845409274101257, 测试损失值为0.934529721736908,测试准确率为0.012357142857142834
# 第59/800次训练，训练损失值为0.18051037192344666, 测试损失值为0.9252907037734985,测试准确率为0.011999999999999978
# 第60/800次训练，训练损失值为0.1849522590637207, 测试损失值为0.9191434383392334,测试准确率为0.011142857142857125
# 第61/800次训练，训练损失值为0.13645750284194946, 测试损失值为0.9041004776954651,测试准确率为0.01157142857142855
# 第62/800次训练，训练损失值为0.13853219151496887, 测试损失值为0.908447265625,测试准确率为0.012857142857142834
# 第63/800次训练，训练损失值为0.1872054934501648, 测试损失值为0.9264614582061768,测试准确率为0.011142857142857125
# 第64/800次训练，训练损失值为0.13367655873298645, 测试损失值为0.9211075901985168,测试准确率为0.011642857142857127
# 第65/800次训练，训练损失值为0.1360434591770172, 测试损失值为0.8939427733421326,测试准确率为0.012999999999999977
# 第66/800次训练，训练损失值为0.12839272618293762, 测试损失值为0.8790349364280701,测试准确率为0.01371428571428569
# 第67/800次训练，训练损失值为0.15359264612197876, 测试损失值为0.8975406885147095,测试准确率为0.012285714285714266
# 第68/800次训练，训练损失值为0.14699572324752808, 测试损失值为0.9137976765632629,测试准确率为0.011142857142857125
# 第69/800次训练，训练损失值为0.1415172815322876, 测试损失值为0.8875702619552612,测试准确率为0.012214285714285691
# 第70/800次训练，训练损失值为0.15889814496040344, 测试损失值为0.8661966919898987,测试准确率为0.013642857142857116
# 第71/800次训练，训练损失值为0.1799893081188202, 测试损失值为0.8780786395072937,测试准确率为0.012642857142857126
# 第72/800次训练，训练损失值为0.12623141705989838, 测试损失值为0.8919560313224792,测试准确率为0.011714285714285696
# 第73/800次训练，训练损失值为0.16212287545204163, 测试损失值为0.8788825869560242,测试准确率为0.01271428571428569
# 第74/800次训练，训练损失值为0.13982364535331726, 测试损失值为0.8667146563529968,测试准确率为0.013285714285714258
# 第75/800次训练，训练损失值为0.18872666358947754, 测试损失值为0.8660653233528137,测试准确率为0.013999999999999974
# 第76/800次训练，训练损失值为0.13660557568073273, 测试损失值为0.8526235222816467,测试准确率为0.011642857142857123
# 第77/800次训练，训练损失值为0.17448070645332336, 测试损失值为0.8353549838066101,测试准确率为0.012928571428571404
# 第78/800次训练，训练损失值为0.1644773781299591, 测试损失值为0.8488076329231262,测试准确率为0.013428571428571404
# 第79/800次训练，训练损失值为0.19079771637916565, 测试损失值为0.8736159205436707,测试准确率为0.012642857142857119
# 第80/800次训练，训练损失值为0.15127700567245483, 测试损失值为0.8660186529159546,测试准确率为0.012428571428571403
# 第81/800次训练，训练损失值为0.18773344159126282, 测试损失值为0.8268095850944519,测试准确率为0.013785714285714259
# 第82/800次训练，训练损失值为0.1556386947631836, 测试损失值为0.8085814118385315,测试准确率为0.015357142857142823
# 第83/800次训练，训练损失值为0.19605371356010437, 测试损失值为0.8240770697593689,测试准确率为0.012428571428571405
# 第84/800次训练，训练损失值为0.16431483626365662, 测试损失值为0.8413607478141785,测试准确率为0.011285714285714269
# 第85/800次训练，训练损失值为0.22803013026714325, 测试损失值为0.8291748762130737,测试准确率为0.012642857142857117

# %%
model_name = "DeepPose"
torch.save(model, model_name + ".model")

# %%
import torch
import torch.nn as nn

model = torch.load("BlazePose.model").to(device)
print(model)
# Out:
# BlazePose(
#   (conv1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv2_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(16, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#       (4): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Identity()
#       (6): ReLU6(inplace=True)
#       (7): Conv2d(72, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv3_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#       (4): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=120, out_features=30, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=30, out_features=120, bias=False)
#           (3): h_sigmoid()
#         )
#       )
#       (6): ReLU6(inplace=True)
#       (7): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv4_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(64, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#       (4): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Identity()
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(200, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv4_b2): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(64, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#       (4): BatchNorm2d(184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Identity()
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(184, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv5_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(128, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#       (4): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=480, out_features=120, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=120, out_features=480, bias=False)
#           (3): h_sigmoid()
#         )
#       )
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv5_b2): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(128, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#       (4): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=672, out_features=168, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=168, out_features=672, bias=False)
#           (3): h_sigmoid()
#         )
#       )
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv6_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(192, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#       (4): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=960, out_features=240, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=240, out_features=960, bias=False)
#           (3): h_sigmoid()
#         )
#       )
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(960, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv2): BlazeBlock(
#     (depth_conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#     (pointwise_conv): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv3): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), groups=16)
#     (pointwise_conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv4): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), groups=32)
#     (pointwise_conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv5): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), groups=64)
#     (pointwise_conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv6): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), groups=128)
#     (pointwise_conv): Conv2d(128, 192, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv7_): Sequential(
#     (0): Conv2d(192, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv8_): Sequential(
#     (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv9_): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv10_): Upsample(scale_factor=2.0, mode=bilinear)
#   (upsample0): Upsample(scale_factor=2.0, mode=bilinear)
#   (upsample1): Upsample(scale_factor=2.0, mode=bilinear)
#   (upsample2): Upsample(scale_factor=2.0, mode=bilinear)
#   (conv11): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): Conv2d(32, 14, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (2): Sigmoid()
#   )
#   (conv12a): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), groups=32)
#     (pointwise_conv): Conv2d(32, 96, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv13a): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), groups=96)
#     (pointwise_conv): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv14a): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), groups=192)
#     (pointwise_conv): Conv2d(192, 288, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv12b): Sequential(
#     (0): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv13b): Sequential(
#     (0): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv14b): Sequential(
#     (0): Conv2d(192, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv15): Sequential(
#     (0): BlazeBlock(
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (depth_conv): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), groups=288)
#       (pointwise_conv): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU6(inplace=True)
#     )
#     (1): BlazeBlock(
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (depth_conv): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), groups=288)
#       (pointwise_conv): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU6(inplace=True)
#     )
#   )
#   (conv16): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=(1, 1))
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=288, out_features=28, bias=True)
#   )
# )

# %%
import matplotlib.pyplot as plt
from torch.autograd import Variable

sample_idx = 1732
# 第几张照片
imgs_list = os.listdir(os.path.join(image_path))  # 获得文件夹内的图片的名称列表
orim = Image.open(os.path.join(image_path, imgs_list[sample_idx - 1]))

image1 = transforms(orim)  # 将图像信息归一化
image1 = Variable(torch.unsqueeze(image1, dim=0).float(), requires_grad=False)

image = image1.to(device)
predict = model(image)  # 把图像数据放进model里
# print(predict)
predict_ = predict.view((14, 2)).cpu().detach().numpy()
# print(predict_)
plt.figure()
for j in ((13, 12), (12, 8), (12, 9), (8, 7), (7, 6), (9, 10), (10, 11), (2, 3), (2, 1), (1, 0), (3, 4), (4, 5), (2, 8), (3, 9)):
    plt.plot([predict_[j[0]][0] * image_size, predict_[j[1]][0] * image_size], [predict_[j[0]][1] * image_size, predict_[j[1]][1] * image_size], color='b')

x = [predict_[i][0] * image_size for i in range(14)]
y = [predict_[i][1] * image_size for i in range(14)]
plt.scatter(np.array(x), np.array(y), color = 'red', s = 6)

# img = np.transpose(orim, (1, 2, 0))
# img = img[:,:,-1::]
plt.imshow(orim.resize((image_size, image_size)))
